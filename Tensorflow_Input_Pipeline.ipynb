# %%
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
daily_sales_numbers = [24,32,14,-2,7,19,28]

# %%
tf_dataset = tf.data.Dataset.from_tensor_slices(daily_sales_numbers)

tf_dataset = tf_dataset.filter(lambda x: x>0).map(lambda y: y*72).shuffle(2).batch(3)

for sales in tf_dataset.as_numpy_iterator():
    print(sales)
# Out:
# [1728 1008  504]
# [2304 2016 1368]

# %%
images_ds = tf.data.Dataset.list_files('images/*/*', shuffle=False)

for file in images_ds.take(3):
    print(file.numpy())
# Out:
# b'images\\cats\\1440.jpg'
# b'images\\cats\\2022-cute-cat-moments.jpg'
# b'images\\cats\\3-17-5-27-1-5-13m.jpg'

# %%
images_ds = images_ds.shuffle(50) #take a example of buffer so basically it stores 200 images first then again other images

for file in images_ds.take(5):
    print(file.numpy())
# Out:
# b'images\\cats\\cute-white-kitten-1024x678.jpg'
# b'images\\dogs\\e04c8c32-f536-41d9-919c-e04e41589157_can+dogs+eat+bread+_281_29.jpg'
# b'images\\dogs\\Screen-Shot-2024-04-01-at-12.30.27-PM-768x597.jpg'
# b'images\\dogs\\Can-Dogs-Eat-Bread (2).jpg'
# b'images\\cats\\pexels-photo-4017827.jpeg_cs=srgb&dl=pexels-muaz-aj-1782491-4017827.jpg'

# %%
class_names = ["cat", "dog"]

# %%
image_count = len(images_ds)

image_count #So it means total 180 images we have in a folder
# Out:
# 180

# %%
train_size = int(image_count*0.8) #So it means 80 percent data is for training

train_ds = images_ds.take(train_size) #it will take first 80 percent of data means images
test_ds = images_ds.skip(train_size) #it will skip those images which were taken by train_ds. So it means

# %%
len(train_ds)
# Out:
# 144

# %%
len(test_ds)
# Out:
# 36

# %%
def get_label(file_path):
    import os
    return tf.strings.split(file_path, os.path.sep)[-2]
        # return file_path.split("\\")[-2] this is not supported by tensorflow library so we use other way

# %%
def process_image(file_path):
    label = get_label(file_path)

    img = tf.io.read_file(file_path)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, [128,128])

    return img, label

# %%
def scale(image, label):

        scaled_image = image/255
        return scaled_image, label

# %%
for t in train_ds.take(5):
    print(t.numpy())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 2
#       1 for t in train_ds.take(5):
# ----> 2     print(t.numpy())
#
# AttributeError: 'tuple' object has no attribute 'numpy'

# %%
for label in train_ds.map(get_label):
    print(label) #this we done was for y label.Now we will do it for X label.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 for label in train_ds.map(get_label):
#       2     print(label)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:2341, in DatasetV2.map(self, map_func, num_parallel_calls, deterministic, synchronous, use_unbounded_threadpool, name)
#    2336 # Loaded lazily due to a circular dependency (dataset_ops -> map_op ->
#    2337 # dataset_ops).
#    2338 # pylint: disable=g-import-not-at-top,protected-access
#    2339 from tensorflow.python.data.ops import map_op
# -> 2341 return map_op._map_v2(
#    2342     self,
#    2343     map_func,
#    2344     num_parallel_calls=num_parallel_calls,
#    2345     deterministic=deterministic,
#    2346     synchronous=synchronous,
#    2347     use_unbounded_threadpool=use_unbounded_threadpool,
#    2348     name=name,
# ...

# %%
train_ds = train_ds.map(process_image)
for img, label in train_ds.take(3):
        print("image: ", img)
        print("label: ", label)
# Out:
# image:  tf.Tensor(
# [[[ 67.618164  85.453125  25.889648]
#   [ 94.01367  102.68164   28.105469]
#   [ 86.96387   79.88281   25.460938]
#   ...
#   [ 90.802734 100.13672   41.307617]
#   [ 95.16211  101.231445  42.884766]
#   [101.80957  111.25293   59.40918 ]]
#
#  [[ 70.58984   89.8584    39.003906]
#   [ 60.038086  82.6582    24.886719]
#   [102.57031  101.89844   53.745117]
#   ...
#   [118.44238  122.677734  75.23047 ]
#   [ 64.59863   89.96289   23.932617]
#   [ 75.42871  105.00195   44.760742]]
#
#  [[ 82.7832    98.069336  27.271484]
#   [111.86328  117.40332   50.288086]
#   [109.25781  122.03418   50.03418 ]
#   ...
#   [ 80.4082    89.836914  29.875977]
#   [ 71.71973   78.981445  22.875   ]
#   [ 65.85449   79.65234   23.805664]]
#
#  ...
#
#  [[ 57.655273  24.342773   5.      ]
#   [116.83496   63.43457   54.512695]
#   [141.05176   80.05176   78.72949 ]
#   ...
#   [ 71.63379   54.554688  29.499023]
#   [ 68.05078   62.09375   37.154297]
# ...

# %%
trains_ds = train_ds.map(scale)

for image, label in train_ds.take(3):
    print("image: ", images.numpy()[0][0])
    print("label: ", label.numpy())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       1 trains_ds = train_ds.map(scale)
#       3 for image, label in train_ds.take(3):
# ----> 4     print("image: ", images.numpy()[0][0])
#       5     print("label: ", label.numpy())
#
# NameError: name 'images' is not defined
